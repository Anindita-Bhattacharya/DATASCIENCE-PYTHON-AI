# %% [markdown]
# REGRESSION PLOT

# %%
import pandas as pd
import seaborn as sns
data={'Study Hours':[1,2,3,4,5],
      'Exam Score':[50,60,70,80,90]
     }
df=pd.DataFrame(data)
plt.figure(figsize=(8,6))
sns.regplot(x='Study Hours',y='Exam Score',data=df)
plt.title("Regression Plot of Study Hour vs Exam Score")
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.show()
